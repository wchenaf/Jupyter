# %%
import importlib
import import_ipynb
import searchsub
import findrep

# %%
for i in range(720,730):
    num= '%03d' % i
    findmag('abp',num)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-b6b6a1b83255> in <module>()
#       1 for i in range(720,730):
#       2     num= '%03d' % i
# ----> 3     findmag('abp',num)
#
# TypeError: findmag() takes 1 positional argument but 2 were given

# %%
result=findmag(['snis','310'])
for x in result:
    print(x)
# Out:
# SNIS-310开始搜索:
#
# snis-310r有带字幕链接
# -------------------------------------------------------------------------
#
# snis-310r有带字幕链接
# 网址：
# https://m.zhongziso.com/list/snis-310r/1
# 磁力链接：
# magnet:?xt=urn:btih:ead074bab47295e2bc9fa783a1748bec55123636
# magnet:?xt=urn:btih:0752469a7ae1eb1f78a1dda4ee09f3df28c08473
# magnet:?xt=urn:btih:D6708148C20E481B079B666C0CD3C47C1003EEAF

# %%
importlib.reload(findrep)
import findrep
# Out:
# importing Jupyter notebook from findrep.ipynb
# g:/3
# 821.9502763748169
# 21986.757677078247
#
# g:/Best
# 153.2799415588379
# 192200.15953540802
#
# g:/BEST1
# 47.095383644104004
# 645783.598033905
#
# g:/BESTU
# 427.4110221862793
# 6008.165212631226
#
# g:/Checked
# 4.38690185546875e-05
# 4028144.711725235
#
# g:/国产种子
# 0.49075794219970703
# 1.3572578430175781
#
# g:1/HND-536R
# 1064.6414651870728
# 1141.443021774292
#
# g:2/09-10 中文字幕新作10連發
# 2067.0197620391846
# 13206.318145751953
#
# g:2/09-14 中文字幕新作10連發
# 1988.0569486618042
# 11768.001653671265
#
# g:2/09-15 中文字幕新作10連發
# 2474.9660606384277
# 13213.985960960388
#
# g:2/09-16 中文字幕新作10連發
# 2042.3001832962036
# 12741.934643745422
#
# g:3\星國冠希玩遍女網紅完整收錄/第1位Bunnyjanjan (janella ooi)就是新聞說的58部女主角，全部都是同一人，幾乎都不脫內衣，但公認最正!
# 137.9784460067749
# 2117.1382026672363
#
# g:3\星國冠希玩遍女網紅完整收錄/第2位美妝達人bellywellyjelly，是這次事件「星國冠希」的女朋友
# 101.08349800109863
# 970.9398279190063
#
# g:3\星國冠希玩遍女網紅完整收錄/第3位樂團的女主唱Abbey Tan (Abymonsta)
# 57.87941932678223
# ...

# %%
print(len(findrep.nonsublist))
print(findrep.nonsublist)
# Out:
# 629
# ...

# %%
importlib.reload(searchsub)
import searchsub
# Out:
# importing Jupyter notebook from searchsub.ipynb
# searchsub defined
# ofje-124的女优是:
# ['ofje-124', ['希崎ジェシカ', '湊莉久', '三上悠亜', '羽咲みはる', '妃月るい', '笹川りほ', '悠月アイシャ', '桃園みらい', '梅田みのり', '柳みゆう', '辻本杏', '水卜さくら']]
# ofje-124
# ['希崎ジェシカ', '湊莉久', '三上悠亜', '羽咲みはる', '妃月るい', '笹川りほ', '悠月アイシャ', '桃園みらい', '梅田みのり', '柳みゆう', '辻本杏', '水卜さくら']

# %%
from multiprocessing import Pool
from multiprocessing.dummy import Pool as ThreadPool

list1=[]
for nonsubcode in findrep.nonsublist:
    index_=nonsubcode.find('-')
    prefix=nonsubcode[:index_].lower()
    num=nonsubcode[index_+1:]
    list1.append([prefix,num])
    
pool = ThreadPool()
results=pool.map(searchsub.findmag,list1)
# Out:
# ACY-017开始搜索:DAP-047开始搜索:FSET-501开始搜索:HONB-052开始搜索:
#
# IPZ-580开始搜索:KTDS-449开始搜索:MIAD-758开始搜索:
#
# MIDD-996开始搜索:
#
# MUM-193开始搜索:
#
# NNPJ-166开始搜索:
#
#
#
#
#
# PTKS-054开始搜索:
# SIRO-2416开始搜索:
#
#
#
#
#
#
#
#
# midd-996c有带字幕链接
# ptks054c有带字幕链接
# fset501c有带字幕链接
# -------------------------------------------------------------------------
#
# AMA-023开始搜索:
#
# -------------------------------------------------------------------------
#
# HUNTA-204开始搜索:
#
# -------------------------------------------------------------------------
#
# IPZ-667开始搜索:
#
# -------------------------------------------------------------------------
#
# MIGD-456开始搜索:
#
# -------------------------------------------------------------------------
#
# PTKS-055开始搜索:
#
# -------------------------------------------------------------------------
#
# MIAD-779开始搜索:
#
# -------------------------------------------------------------------------
#
# MUM-216开始搜索:
#
# ...

# %%
for result in results:
    if len(result)>0:
        for line in result:
            print(line)
# Out:
# SQTE-196
# ['君色花音', '四ツ葉うらら', '関根奈美', '音ノ木さくら', '七瀬萌', 'ななせ麻衣']
# SRS-081
# []
# SSNI-301
# ['三上悠亜']
# SSNI-302
# ['星野ナミ']
# SSNI-303
# ['葵つかさ']
# SSNI-304
# ['夢乃あいか']
# SSNI-305
# ['橋本ありな']
# SSNI-307
# ['吉高寧々']
# SSNI-308
# ['架乃ゆら']
# SSNI-310
# ['坂道みる']
# STAR-835
# ['神坂ひなの']
# SUPA-370
# []
# SUPA-371
# []
# SUPA-372
# []
# SVDVD-683
# []
# UMSO-205
# ['初芽里奈', '大原友美', '小宮山ゆき', '高梨あゆみ', '青井いちご', '日向あみる', '井上みづき', '秋山しおり', 'さくらみゆき', '星咲セイラ', '陽木かれん', '高槻ルナ', '跡美しゅり', '安達メイ', '渡辺もも', '星まりあ', '加賀美シュナ', '荒木まい', '明海こう（小泉まり）', '久我かのん', '石原あい', '川越ゆい', '小川めるる', '愛須心亜', '彩城ゆりな', '舞園にこ', 'さとう愛理', '朝比奈ゆの', '早乙女ゆい', 'あまね弥生', '鈴木そら', '七海ゆあ', '白咲まどか', '春日野結衣', '土屋あさみ', '野々宮ここみ', '田中ユカリ', '星奈あい', '一ノ瀬もも', 'ひなみれん', '琴羽雫', '月本愛', 'あず希', 'あすな小春', '碧木凛', '澄川鮎', '愛音くぅ', '愛瀬美希', 'あおいれな', '星川麻紀']
# VEC-258
# ['花咲いあん']

# %%
from multiprocessing import Pool
from multiprocessing.dummy import Pool as ThreadPool

def sortFunc(e):
    return e[1]

    
pool = ThreadPool()
results=pool.map(searchsub.findactress,findrep.codelist)
results.sort(key=sortFunc)

# %%
for result in results:
    if len(result[1])>0 or 1:
        print()
        for line in result:
            print(line)
# Out:
# CPSN-001
# []
#
# DAP-047
# []
#
# DCX-071
# []
#
# EBOD-607
# []
#
# FIV-007
# []
#
# GDHH-020
# []
#
# GDJU-027
# []
#
# Gachinco gachip361-
# []
#
# HAWA-140
# []
#
# HONB-052
# []
#
# HUNTA-204
# []
#
# KTKL-032
# []
#
# LOVE-38
# []
#
# LOVE-82
# []
#
# MIAD-955
# []
#
# MIAE-127
# []
#
# MIAE-288
# []
#
# MISM-028
# []
#
# MKBD-
# []
#
# MKBD-
# []
#
# MKBD-
# []
#
# MUM-098
# []
#
# MUM-191
# []
#
# MUM-193
# []
#
# MXGS-459
# []
#
# NNPJ-075
# []
#
# NNPJ-166
# []
#
# PT-157
# []
#
# PTKS-048
# []
#
# RCT-297
# []
#
# SABA-365
# []
#
# SAMA-484
# []
#
# SAMA-789
# []
#
# SDMU-806
# []
#
# SHIBP-008
# []
#
# SIRO-1690
# []
#
# SIRO-1736
# []
#
# SIRO-2416
# []
#
# SIV-029
# []
#
# SRS-042
# []
#
# SW-296
# []
#
# SW-327
# []
#
# SW-351
# []
#
# SW-439
# []
#
# TUS-057
# []
#
# UPSM-215
# []
#
# gachi1061-
# []
#
# ともみ ちゃん -
# []
#
# ZUKO-084
# ['AIKA', '北川エリカ', '夏目優希', '奥菜アンナ']
#
# ZUKO-102
# ['AIKA', '松本メイ', 'サリー', '長谷川モニカ']
#
# EBOD-500
# ['NAOMI']
#
# EBOD-519
# ['NAOMI']
# ...
