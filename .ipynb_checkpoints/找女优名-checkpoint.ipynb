# %%
import os 
import time
import requests
import json
import re
import pandas as pd
from multiprocessing import Pool
from multiprocessing.dummy import Pool as ThreadPool


indexnum=0

#list of [片名，路径]
namelist=[]

#已下载无字幕番号合集
nonsublist=[]

def sortFunc(e):
    return e[1]

def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return (total_size/1024/1024)



def largets_file(start_path = '.'):
    largest=''
    max_size=0
    for f in next( os.walk(start_path) )[2]:
        fp = os.path.join(start_path, f)
        size=os.path.getsize(fp)
        if size>max_size:
            max_size=size
            largest=fp
    return largest

def largets_file_size(start_path = '.'):
    #print(start_path)
    max_size=0
    if len(next( os.walk(start_path) )[2])>0:
        for f in next( os.walk(start_path) )[2]:
            fp = os.path.join(start_path, f)
            size=os.path.getsize(fp)
            if size>max_size:
                max_size=size
    return max_size/1024/1024


headers = {'User-Agent':
               'Mozilla/5.0 (Windows NT 10.0; WOW64)\
               AppleWebKit/537.36(KHTML, like Gecko)\
               Chrome/55.0.2883.87 Safari/537.36'}


def findmag(prefixnum):
    prefix=prefixnum[0]
    num=prefixnum[1]
    result=[]
    print(prefix.upper()+'-'+num+'开始搜索:')
    print()
    maglist=[]
    keywordlist=[]
    
    keywordlist.append(prefix+'-'+num+'r')
    keywordlist.append(prefix+'-'+num+'c')
    keywordlist.append(prefix+num+'c')
    keywordlist.append(prefix+num+'cmp4')
    
    for keyword in keywordlist:
        url = 'https://m.zhongziso.com/list/'+keyword+'/1'

        web = requests.get(url, headers=headers)
        web.encoding = 'utl-8'

        Page = web.text

        indexr=Page.find('<span class="highlight">'+keyword+'</span>')

        if (indexr!=-1):
            print(keyword+'有带字幕链接')
            result.append(keyword+'有带字幕链接')
            result.append('网址：')
            result.append(url)
            result.append('磁力链接：')

            maglist=re.findall('magnet:/?.*?(?=")', Page)
            for item in maglist:
                result.append(item)
            result.append(' ')
    
    print('-------------------------------------------------------------------------')
    print()
    return result
        
def findactress(code):

    url = 'https://www.javbus.com/'+code

    web = requests.get(url, headers=headers)
    web.encoding = 'utl-8'

    Page = web.text
    #<div class="star-name"><a href="https://www.javbus.com/star/2xi" title="葵つかさ">葵つかさ</a></div>

    actresslist=re.findall(r'<div class="star-name"><a href="https://www.javbus.com/star/.*?>(.*?)<', Page)

    return [code,actresslist]

# %% [markdown]
# # 所有子文件夹的女优

# %%
#需找演员的番号列表

codelist=[]


drivelist=[]
drivelist.append(os.walk(r"g:/renamed"))
#drivelist.append(os.walk(r"g:/BEST1"))
#drivelist.append(os.walk(r"g:/Checked"))
#drivelist.append(os.walk(r"g:/Collected"))

#drivelist.append(os.walk(r"i:/Checked (Non Subbed)/"))


for g in drivelist:
    for path,dir_list,file_list in g:  
        for dir_name in dir_list:
            index_=dir_name.find('-')
            if (index_!=-1) and (index_<len(dir_name)-1):
                indexnum=index_+1
                while (dir_name[indexnum].isdigit()) and (indexnum<len(dir_name)):
                    indexnum+=1
                    if indexnum==len(dir_name):
                        break
                code=dir_name[:indexnum]

                codelist.append(code)

codelist.sort()

pool = ThreadPool()
results=pool.map(findactress,codelist)
results.sort(key=sortFunc)
for result in results:
    if len(result[1])>0 or 1:
        print()
        for line in result:
            print(line)
# Out:
# AP-255
# []
#
# AP-565
# []
#
# AP-565
# []
#
# BAZX-138
# []
#
# CLUB-486
# []
#
# DVDMS-174
# []
#
# DVDMS-234
# []
#
# GS-198
# []
#
# HUNTA-445
# []
#
# HUNTA-453
# []
#
# HUNTA-456
# []
#
# HUNTA-461
# []
#
# HUNTA-462
# []
#
# HUNTA-471
# []
#
# KANE-004
# []
#
# KAWD-910
# []
#
# KTKZ-030
# []
#
# MDTM-374
# []
#
# MDTM-408
# []
#
# MIAE-260
# []
#
# MMGH-087
# []
#
# NHDTB-098
# []
#
# NHDTB-139
# []
#
# NHDTB-139
# []
#
# NKKD-088
# []
#
# NNPJ-289
# []
#
# NNPJ-292
# []
#
# NPV-008
# []
#
# ONEZ-148
# []
#
# OYC-192
# []
#
# PHX-008
# []
#
# PRED-066
# []
#
# RCTD-118
# []
#
# SABA-419
# []
#
# SCPX-274
# []
#
# SPZ-993
# []
#
# SS-054
# []
#
# SUPA-370
# []
#
# SUPA-371
# []
#
# SUPA-372
# []
#
# SVDVD-683
# []
#
# YST-86
# []
#
# HND-228
# ['AIKA']
#
# KIBD-232
# ['AIKA', '緒川りお', '若菜奈央', '椎名そら', '麻里梨夏', '姫川ゆうな', '千夏まりな', '天野美優', '愛瀬美希', '桜庭このみ', 'SARA']
#
# PPPD-661
# ['JULIA']
#
# ABP-201
# ['あやみ旬果']
#
# ABP-629
# ['あやみ旬果']
#
# MDB-911
# ['なつめ愛莉', 'あおいれな', 'あかね葵', '雛菊つばさ']
#
# HBAD-428
# ['みつ葉（菊川みつ葉）']
#
# HND-506
# ['ビビアン・リン']
#
# HND-536
# ['一ノ瀬梓']
#
# JUY-532
# ['一色桃子']
#
# JUFD-881
# ['七瀬あいり']
#
# JUY-556
# ['並木塔子']
#
# POST-448
# ['二宮和香', '市川つばさ', 'かさいあみ', '松井レナ']
#
# ONGP-108
# ['五十嵐星蘭']
#
# HND-526
# ['佐々木あき']
#
# MMNA-015
# ['佐々木あき']
#
# HND-414
# ['佐々波綾']
#
# PRTD-016
# ['佐々波綾']
#
# MKMP-230
# ['佐倉絆']
#
# NGOD-079
# ['光井ひかり']
#
# MEYD-396
# ['八乃つばさ']
#
# MVSD-355
# ['初美りん', '八乃つばさ']
#
# UMSO-205
# ['初芽里奈', '大原友美', '小宮山ゆき', '高梨あゆみ', '青井いちご', '日向あみる', '井上みづき', '秋山しおり', 'さくらみゆき', '星咲セイラ', '陽木かれん', '高槻ルナ', '跡美しゅり', '安達メイ', '渡辺もも', '星まりあ', '加賀美シュナ', '荒木まい', '明海こう（小泉まり）', '久我かのん', '石原あい', '川越ゆい', '小川めるる', '愛須心亜', '彩城ゆりな', '舞園にこ', 'さとう愛理', '朝比奈ゆの', '早乙女ゆい', 'あまね弥生', '鈴木そら', '七海ゆあ', '白咲まどか', '春日野結衣', '土屋あさみ', '野々宮ここみ', '田中ユカリ', '星奈あい', '一ノ瀬もも', 'ひなみれん', '琴羽雫', '月本愛', 'あず希', 'あすな小春', '碧木凛', '澄川鮎', '愛音くぅ', '愛瀬美希', 'あおいれな', '星川麻紀']
#
# BBI-209
# ['北川エリカ']
#
# MDB-867
# ['北川エリカ', '鈴木真夕', '阿部乃みく', '泉りおん']
#
# JUY-552
# ['南あや']
#
# PRED-086
# ['南梨央奈']
#
# MMTA-011
# ['友田彩也香']
#
# JUY-531
# ['友田真希']
#
# POST-447
# ['吉川あいみ', '小峰みこ', '星川ういか', '鈴ノ木桜']
#
# RCTD-119
# ['名森さえ']
#
# HND-332
# ['向井藍']
#
# JUFD-921
# ['君島みお']
#
# MDTM-383
# ['君色華奈']
#
# ABP-442
# ['坂井里美']
#
# RKI-462
# ['坂咲みほ']
#
# SSNI-310
# ['坂道みる']
#
# MUKD-455
# ['天音優愛']
#
# HND-230
# ['宇佐美まい']
#
# PPPD-676
# ['宝田もなみ']
#
# MCSR-175
# ['小峰みこ']
#
# KAWD-774
# ['小島みなみ', '緒川りお', 'さくらゆら']
#
# JUY-455
# ['川北りな']
#
# PGD-940
# ['川村まや', '宮崎あや', 'さとう愛理', '跡美しゅり', '宮沢ゆかり', '泉ののか']
#
# MIFD-046
# ['御坂りあ']
#
# PRED-082
# ['新沢平蘭']
#
# IENE-907
# ['早乙女らぶ', '前田えま（加藤えま）', '宮村ななこ', '藍原あおい']
#
# IPX-053
# ['明里つむぎ']
#
# TOMN-157
# ['星奈あい']
#
# HIZ-022
# ['春咲りょう']
#
# PPPD-675
# ['月本愛', '天野美優']
#
# PRED-085
# ['有坂深雪']
#
# PRTD-015
# ['有坂深雪']
#
# PRED-087
# ['本田岬']
#
# IPX-167
# ['本田岬', '水野朝陽', '有原あゆみ']
#
# BDSR-223
# ['松嶋葵', '美木ななみ', '杉崎絵里奈']
#
# IPX-173
# ['松永さな']
#
# KAWD-877
# ['桜もこ']
#
# IPZ-462
# ['桜井あゆ', '立花美涼']
#
# BBI-208
# ['桜木凛']
#
# BBI-208
# ['桜木凛']
#
# MDB-866
# ['森はるら', '斉藤みゆ', '北川りこ', '藤波さとり']
#
# AQSH-022
# ['森沢かな（飯岡かなこ）']
#
# HND-329
# ['椎名そら']
#
# HND-431
# ['椎名そら']
#
# WANZ-759
# ['椎名そら']
#
# HNDS-055
# ['椎名そら', '麻里梨夏', '河南実里', '星奈あい']
#
# IPZ-861
# ['榊梨々亜']
#
# POST-446
# ['横山凛', '彩奈リナ（七原あかり）', '石原ルリカ', '鈴ノ木桜']
#
# SSNI-106
# ['橋本ありな']
#
# PPPD-678
# ['武田真']
#
# MIAE-266
# ['水野朝陽']
#
# MEYD-398
# ['永井みひな']
#
# SSNI-240
# ['河北彩花']
#
# HND-486
# ['河南実里']
#
# MDB-912
# ['河音くるみ', '月本愛', '宝田もなみ', '水川スミレ']
#
# MIAE-262
# ['波多野結衣']
#
# HND-337
# ['浅田結梨']
#
# RCTD-121
# ['浜崎真緒', '橘メアリー', '澁谷果歩', '森はるら', '二宮和香', '笹倉杏', '新垣智江', '優月まりな', '宇多田あみ']
#
# NGOD-080
# ['熊宮由乃']
#
# MIAE-272
# ['玉木くるみ', '天野美優', '美谷朱里', 'はるかみらい']
#
# HND-324
# ['相川潤']
#
# AVOP-227
# ['石原莉奈']
#
# STAR-835
# ['神坂ひなの']
#
# RCTD-116
# ['神坂ひなの', '石川祐奈', '千夏南那', '優木カリナ']
#
# HND-546
# ['神谷充希']
#
# IPZ-568
# ['立花美涼']
#
# SHKD-583
# ['立花美涼']
#
# HND-415
# ['笹倉杏']
#
# HND-333
# ['篠田あゆみ']
#
# MEYD-399
# ['篠田ゆう']
#
# MEYD-399
# ['篠田ゆう']
#
# RBD-907
# ['美谷朱里', '神宮寺ナオ']
#
# HND-336
# ['落合まりえ']
#
# ABP-374
# ['藤井有彩']
#
# RCTD-117
# ['藤波さとり']
#
# CST-005
# ['西内るな']
#
# HND-331
# ['西園寺ミヅキ']
#
# IPX-131
# ['西宮ゆめ']
#
# ONEZ-062
# ['跡美しゅり']
#
# ABP-288
# ['輝月あんり']
#
# PPPD-681
# ['込山りか']
#
# HND-326
# ['通野未帆']
#
# SSNI-239
# ['阿由葉あみ']
#
# HND-413
# ['霧島かほ']
#
# MIAE-261
# ['高杉麻里']
#
# MISM-100
# ['高杉麻里']
#
# MVSD-354
# ['高杉麻里']
#
# HND-537
# ['麻里梨夏']

# %% [markdown]
# # Collected文件夹检查

# %%
drivelist=[]

root=r"g:/Collected"
for dir_name in next( os.walk(root) )[1]:
    drivelist.append(dir_name)

for actressname in drivelist:
    print('------------------------------------------')
    print(actressname)
    path=os.path.join(root, actressname)
    g=os.walk(path)
    codelist=[]
    for path,dir_list,file_list in g:  
        
        for dir_name in dir_list:
            index_=dir_name.find('-')
            if (index_!=-1) and (index_<len(dir_name)-1):
                indexnum=index_+1
                while (dir_name[indexnum].isdigit()) and (indexnum<len(dir_name)):
                    indexnum+=1
                    if indexnum==len(dir_name):
                        break
                code=dir_name[:indexnum]

                codelist.append(code)

    codelist.sort()

    pool = ThreadPool()
    results=pool.map(findactress,codelist)
    results.sort(key=sortFunc)
    for result in results:
        if len(result[1])>0 and actressname not in result[1]:
            print()
            for line in result:
                print(line)
# Out:
# ------------------------------------------
# Julia
#
# MIDD-994
# ['JULIA']
# ------------------------------------------
# NAOMI
# ------------------------------------------
# RION
#
# SNIS-166
# ['宇都宮しをん']
# ------------------------------------------
# sex friend
# ------------------------------------------
# あおいれな（葵玲奈）
#
# MIAD-911
# ['あおいれな']
#
# MIAE-046
# ['あおいれな']
# ------------------------------------------
# あべみかこ（安部未华子）
#
# BKKG-014
# ['あべみかこ']
#
# CWM-241
# ['あべみかこ']
#
# HND-218
# ['あべみかこ']
#
# HND-282
# ['あべみかこ']
#
# MIAD-758
# ['あべみかこ']
#
# MIAD-779
# ['あべみかこ']
#
# MIAD-956
# ['あべみかこ']
#
# MIAE-017
# ['あべみかこ']
#
# MIGD-649
# ['あべみかこ']
#
# MIGD-699
# ['あべみかこ']
#
# MIGD-736
# ['あべみかこ']
#
# MKMP-138
# ['あべみかこ']
#
# NHDTA-929
# ['あべみかこ']
#
# WANZ-468
# ['あべみかこ']
#
# WANZ-521
# ['あべみかこ']
#
# WANZ-540
# ['あべみかこ']
#
# MIAD-977
# ['あべみかこ', '椎名そら']
#
# ZUKO-121
# ['あべみかこ', '相原翼', '北川ゆず', '麻里梨夏']
#
# MIGD-702
# ['上原亜衣', 'あべみかこ']
# ------------------------------------------
# あやみ旬果
# ------------------------------------------
# さくらゆら（樱由罗）
#
# KAWD-756
# ['さくらゆら']
#
# KAWD-775
# ['さくらゆら']
#
# KAWD-785
# ['さくらゆら']
#
# EBOD-227
# ['ちとせりこ']
# ------------------------------------------
# ななせ麻衣（菅野紗世）
#
# JUY-343
# ['ななせ麻衣']
#
# KTRA-029
# ['ななせ麻衣']
#
# MDTM-339
# ['ななせ麻衣']
#
# WANZ-668
# ['南田みさき']
#
# WANZ-707
# ['南田みさき']
# ------------------------------------------
# ほしの景子
# ------------------------------------------
# 七沢みあ
# ------------------------------------------
# 七瀬ルナ
# ------------------------------------------
# 三上悠亜
#
# SNIS-184
# ['星野ナミ']
# ------------------------------------------
# 三田杏
# ------------------------------------------
# 上原瑞穂
# ------------------------------------------
# 並木優
# ------------------------------------------
# 乙都さきの
# ------------------------------------------
# 九重かんな
# ------------------------------------------
# 二宮和香（能美ちなつ）
#
# FSET-735
# ['なつめ愛莉', '二宮和香']
#
# JKSR-258
# ['二宮和香', '西内るな']
#
# EYAN-048
# ['能美ちなつ']
# ------------------------------------------
# 井上みづき
# ------------------------------------------
# 伊東ちなみ
# ------------------------------------------
# 凰かなめ
# ------------------------------------------
# 初川みなみ
# ------------------------------------------
# 北野のぞみ
# ------------------------------------------
# 双葉良香
# ------------------------------------------
# 古川いおり
# ------------------------------------------
# 吉川蓮
# ------------------------------------------
# 吉高寧々
# ------------------------------------------
# 園田みおん
# ------------------------------------------
# 土屋あさみ
# ------------------------------------------
# 夏目彩春
# ------------------------------------------
# 大橋未久
# ------------------------------------------
# 天使もえ
# ------------------------------------------
# 宮咲りのん
# ------------------------------------------
# 小島みなみ
# ------------------------------------------
# 岸田歩美
# ------------------------------------------
# 川相美月
# ------------------------------------------
# 市川まさみ
# ------------------------------------------
# 希島あいり
# ------------------------------------------
# 希志あいの
# ------------------------------------------
# 希美まゆ
# ------------------------------------------
# 幸田ユマ
# ------------------------------------------
# 庵野杏
# ------------------------------------------
# 愛世くらら
# ------------------------------------------
# 明日花キララ
# ------------------------------------------
# 明里つむぎ
# ------------------------------------------
# 星咲セイラ
# ------------------------------------------
# 星奈あい
# ------------------------------------------
# 星川なつ
# ------------------------------------------
# 春咲りょう
# ------------------------------------------
# 有坂深雪
# ------------------------------------------
# 東凛
# ------------------------------------------
# 林ゆな
# ------------------------------------------
# 架乃ゆら
# ------------------------------------------
# 柚月ひまわり
# ------------------------------------------
# 栗衣みい
# ------------------------------------------
# 桃乃木かな
# ------------------------------------------
# 桃谷繪里香
#
# GNE-176
# ['あやみ旬果', '鈴村あいり', '柚月あい', '桃谷エリカ']
#
# GNE-105
# ['柚原綾', '酒井ももか', '桃谷エリカ']
#
# ABP-145
# ['桃谷エリカ']
#
# ABP-159
# ['桃谷エリカ']
#
# ABP-171
# ['桃谷エリカ']
#
# ABP-178
# ['桃谷エリカ']
#
# CHN-037
# ['桃谷エリカ']
#
# PPT-018
# ['桃谷エリカ']
#
# SRS-022
# ['桃谷エリカ']
# ------------------------------------------
# 桜空もも
# ------------------------------------------
# 森永久留美
# ------------------------------------------
# 森沢かな（飯岡かなこ）
# ------------------------------------------
# 椎名そら 节选
#
# JUFD-704
# ['椎名そら']
#
# MIAD-991
# ['椎名そら']
#
# MMNA-006
# ['椎名そら']
#
# NKKD-011
# ['椎名そら']
#
# NNPJ-118
# ['椎名そら']
#
# NNPJ-126
# ['椎名そら']
#
# NNPJ-134
# ['椎名そら']
#
# WANZ-550
# ['椎名そら']
#
# WANZ-567
# ['椎名そら']
#
# WANZ-575
# ['椎名そら']
# ------------------------------------------
# 横山美雪
# ------------------------------------------
# 橋本ありな
# ------------------------------------------
# 水トさくら
#
# MIDE-515
# ['水卜さくら']
#
# MIDE-531
# ['水卜さくら']
#
# MIDE-549
# ['水卜さくら']
#
# MIDE-558
# ['水卜さくら']
#
# MIDE-565
# ['水卜さくら']
#
# MIDE-571
# ['水卜さくら']
#
# MIDE-580
# ['水卜さくら']
#
# MMND-141
# ['水卜さくら']
#
# MMND-143
# ['水卜さくら']
#
# SNIS-917
# ['水卜さくら']
#
# SNIS-937
# ['水卜さくら']
#
# SNIS-960
# ['水卜さくら']
#
# SSNI-005
# ['水卜さくら']
#
# SSNI-025
# ['水卜さくら']
#
# SSNI-048
# ['水卜さくら']
#
# SSNI-094
# ['水卜さくら']
# ------------------------------------------
# 永嶋輝子
# ------------------------------------------
# 汐音まり
# ------------------------------------------
# 河北彩花
# ------------------------------------------
# 河南実里
# ------------------------------------------
# 泷泽萝拉（水咲萝拉）
#
# ABP-031
# ['水咲ローラ（滝澤ローラ）']
#
# ABP-041
# ['水咲ローラ（滝澤ローラ）']
#
# IDBD-577
# ['水咲ローラ（滝澤ローラ）']
#
# IPZ-405
# ['水咲ローラ（滝澤ローラ）']
#
# MAS-087
# ['水咲ローラ（滝澤ローラ）']
# ------------------------------------------
# 浜野友香
#
# KDKJ-057
# ['あんず']
#
# KTRA-023
# ['浜野友夏']
# ------------------------------------------
# 瀬名きらり
# ------------------------------------------
# 瀬野みやび
# ------------------------------------------
# 瑠川リナ
# ------------------------------------------
# 白川メイナ
# ------------------------------------------
# 相沢みなみ
# ------------------------------------------
# 真田春香
# ------------------------------------------
# 石原莉奈
# ------------------------------------------
# 神田るみ
# ------------------------------------------
# 竹内乃愛
# ------------------------------------------
# 竹田ゆめ
# ------------------------------------------
# 笹川りほ
# ------------------------------------------
# 結まきな
# ------------------------------------------
# 美谷朱里
# ------------------------------------------
# 美雪ありす
# ------------------------------------------
# 翼
# ------------------------------------------
# 胡桃たえ
#
# FSTA-023
# ['藤田えり']
# ------------------------------------------
# 花咲はな
# ------------------------------------------
# 芽森しずく（宝生リリー）
#
# RVGG-001
# ['宝生リリー']
#
# SOAV-038
# ['宝生リリー']
#
# HMNF-053
# ['宝生リリー', '理々香']
#
# ABP-100
# ['朝日奈るみな（芽森しずく）']
#
# ABP-115
# ['朝日奈るみな（芽森しずく）']
#
# ABP-135
# ['朝日奈るみな（芽森しずく）']
#
# ABP-146
# ['朝日奈るみな（芽森しずく）']
#
# ABP-161
# ['朝日奈るみな（芽森しずく）']
#
# ABP-172
# ['朝日奈るみな（芽森しずく）']
#
# ABP-196
# ['朝日奈るみな（芽森しずく）']
#
# ABP-204
# ['朝日奈るみな（芽森しずく）']
#
# ABP-223
# ['朝日奈るみな（芽森しずく）']
#
# ABP-234
# ['朝日奈るみな（芽森しずく）']
#
# ABP-242
# ['朝日奈るみな（芽森しずく）']
#
# ABP-257
# ['朝日奈るみな（芽森しずく）']
#
# ORBK-002
# ['朝日奈るみな（芽森しずく）']
#
# PGD-774
# ['朝日奈るみな（芽森しずく）']
#
# PGD-783
# ['朝日奈るみな（芽森しずく）']
#
# PGD-794
# ['朝日奈るみな（芽森しずく）']
#
# PGD-811
# ['朝日奈るみな（芽森しずく）']
#
# PPT-020
# ['朝日奈るみな（芽森しずく）']
#
# RBD-775
# ['朝日奈るみな（芽森しずく）']
#
# SHKD-665
# ['朝日奈るみな（芽森しずく）']
#
# SHKD-675
# ['朝日奈るみな（芽森しずく）']
#
# SHKD-682
# ['朝日奈るみな（芽森しずく）']
#
# SHKD-690
# ['朝日奈るみな（芽森しずく）']
# ------------------------------------------
# 茉莉ひな（宮益ことは）
#
# SDSI-023
# ['宮益ことは']
#
# SDSI-025
# ['宮益ことは']
#
# SDSI-030
# ['宮益ことは']
#
# SDSI-033
# ['宮益ことは']
#
# SDSI-036
# ['宮益ことは']
#
# MDTM-398
# ['茉莉ひな']
#
# MDTM-411
# ['茉莉ひな']
# ------------------------------------------
# 西内るな
# ------------------------------------------
# 西宮ゆめ
# ------------------------------------------
# 西田カリナ
# ------------------------------------------
# 谷田部和沙
# ------------------------------------------
# 跡美しゅり
# ------------------------------------------
# 輝月あんり
# ------------------------------------------
# 辻本杏
# ------------------------------------------
# 鈴村あいり
# ------------------------------------------
# 長瀬麻美
# ------------------------------------------
# 長谷川るい
# ------------------------------------------
# 長谷川リホ 早期
#
# MIDD-992
# ['長谷川リホ']
#
# SOE-852
# ['長谷川リホ']
# ------------------------------------------
# 関根奈美
# ------------------------------------------
# 青井いちご
#
# BUR-427
# ['のぞみ', '平野あおい', '北原えれな']
# ------------------------------------------
# 音あずさ
# ------------------------------------------
# 香苗レノン
# ------------------------------------------
# 高井ルナ
# ------------------------------------------
# 高嶋ゆいか
# ------------------------------------------
# 高橋しょう子
