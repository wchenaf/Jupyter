# %% [markdown]
# # All Definitions

# %%
import os 
import cv2
import pickle
import datetime



#list of [片名，路径]
namelist=[]

#已下载无字幕番号合集
nonsublist=[]


def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return (total_size/1024/1024)



def largets_file(start_path = '.'):
    largest=''
    max_size=0
    for f in next( os.walk(start_path) )[2]:
        fp = os.path.join(start_path, f)
        size=os.path.getsize(fp)
        if size>max_size:
            max_size=size
            largest=fp
    return largest

def largets_file_size(start_path = '.'):
    #print(start_path)
    max_size=0
    if len(next( os.walk(start_path) )[2])>0:
        for f in next( os.walk(start_path) )[2]:
            fp = os.path.join(start_path, f)
            size=os.path.getsize(fp)
            if size>max_size:
                max_size=size
    return max_size/1024/1024

def save_obj(obj, name ):
    with open('obj/'+ name + '.pkl', 'wb') as f:
        pickle.dump(obj, f, pickle.HIGHEST_PROTOCOL)

def load_obj(name ):
    with open('obj/' + name + '.pkl', 'rb') as f:
        return pickle.load(f)



def get_video_height(path):
    vid = cv2.VideoCapture(path)
    height = vid.get(cv2.CAP_PROP_FRAME_HEIGHT)
    return height

def get_size(start_path = '.'):
    total_size = 0
    for dirpath, dirnames, filenames in os.walk(start_path):
        for f in filenames:
            fp = os.path.join(dirpath, f)
            total_size += os.path.getsize(fp)
    return (total_size/1024/1024)

def largets_file(start_path = '.'):
    largest=''
    max_size=0
    for f in next( os.walk(start_path) )[2]:
        fp = os.path.join(start_path, f)
        size=os.path.getsize(fp)
        if size>max_size:
            max_size=size
            largest=fp
    return largest

                
def folder_one_level(root,minsize=0):
    for file_name in next( os.walk(root) )[2]:
        
        fp = os.path.join(root, file_name)
        size=os.path.getsize(fp)/1024/1024
        if size>minsize:
            path=root+'/'+file_name
            index=file_name.rfind('.')
            suffix=file_name[index:]
            video_name=file_name[:index]

            dst=root+'/'+video_name+'/'+file_name

            if not os.path.isdir(root+'/'+video_name):
                os.makedirs(root+'/'+video_name)
            try:
                os.rename(path,dst)
                print(path)
                print(dst)
            except Exception as e:
                print(e)
                print(' ')
    
def final_rename(dir_name,new_name,dst_dir='g:/renamed'):
    new_name.strip()
    dst=os.path.join(dst_dir, new_name)
    if dst.find(' ')!=-1:
        dst=dst.replace(' ','_')
    if dir_name!=new_name:
        print('before: '+path)
        print('after:  '+dst)
        print(' ')
    try:
        os.rename(path,dst)
    except Exception as e:
        if os.path.isdir(dst):
            os.rename(path,dst+'#')
        else:
            print(e)
            print(' ')

def final_check(dir_name,new_name,dst_dir='g:/renamed'):
    new_name.strip()
    dst=os.path.join(dst_dir, new_name)
    if dir_name!=new_name:
        new_name.strip()
        print('before: '+path)
        print('after:  '+dst)
        print(' ')

def findcode(dir_name):
    index_=dir_name.find('-')
    if (index_!=-1) and (index_<len(dir_name)-1):
        indexnum=index_+1
        while (dir_name[indexnum].isdigit()) and (indexnum<len(dir_name)):
            indexnum+=1
            if indexnum==len(dir_name):
                break
        code=dir_name[:indexnum]
    return code

def prt(msg):
    print(msg)
    print(msg,file=f)

trash_dir=r'g:/Trash'

def trash(drive):
    print('-----------------------------------------------------------')
    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
    print('NOW COLLECT TRASH UNDER '+drive)
    print('- - - - - - - - - - - - - - - - - - - - - - - - - - - - - -')
    g=next(os.walk(drive))[1]
    for dir_name in g: 
        path=drive+'/'+dir_name
        trashpath=path+'/trash'
        try:
            os.makedirs(trashpath)
        except Exception as e:
            None
        for dir_name1 in next(os.walk(path))[1]:
            if dir_name1!='trash':
                path1=path+'/'+dir_name1
                dst=trashpath+'/'+dir_name1
                os.rename(path1,dst)
        for file_name in next(os.walk(path))[2]:
            trashed=0
            indexh=dir_name.find('-')
            if indexh!=-1:
                prefix=dir_name[:indexh].lower()
                #print(prefix)
                if file_name.lower().find(prefix)==-1:
                    path1=path+'/'+file_name
                    dst=trashpath+'/'+file_name
                    #print(path1)
                    #print(dst)
                    try:
                        os.rename(path1,dst)
                        trashed=1
                    except Exception as e:
                        print(e)
                        print(' ')
                        
            if (file_name.find('.bc!')!=-1 or file_name.find('-s.jpg')!=-1)and trashed==0:
                path1=path+'/'+file_name
                dst=trashpath+'/'+file_name
                #print(path1)
                #print(dst)
                try:
                    os.rename(path1,dst)
                except Exception as e:
                    print(e)
                    print(' ')
        if len(os.listdir(trashpath))>0:
            print('trash collected in '+path+':')
            #print(os.listdir(trashpath))
            if get_size(trashpath)>(get_size(path)/3):
                print(path+' moved too much into trash')
            print()
        else:
            os.removedirs(trashpath)
    
    print('-----------------------------------------------------------')
    print('-----------------------------------------------------------')
    for dir_name in g: 
        path=drive+'/'+dir_name
        if len(os.listdir(path))>5:
            print(path+' still has more than 5 items')

# %% [markdown]
# # 某文件夹下文件重命名

# %%
root='g:/3'
for dirname in next(os.walk(root))[1]:
    #indexspace=filename.find(' ')
    newname=dirname
    newname=newname.replace('FC2ppv-','FC2PPV-')
    try:
        os.rename(root+'/'+dirname,root+'/'+newname)
    except Exception as e:
        print(e)

# %% [markdown]
# # 生成前缀列表

# %%
#prefix_list=load_obj('prefix_list')
prefix_list=[]
namelist=next( os.walk(r'f:/checked') )[1]

for x in namelist:
    index_=x.find('-')
    prefix=x[:index_].lower()
    if (prefix not in prefix_list) and (len(prefix)<=5) and (len(prefix)>1):
        prefix_list.append(prefix)

prefix_list.append('bur')
prefix_list.append('fc2ppv')
prefix_list.append('aqsh')
prefix_list.append('spz')
prefix_list.append('ppt')
prefix_list.append('madm')
#prefix_list.append('voss')


badlist=['gg','hd','sps','hjd','gs','dv','ss']
for x in badlist:
    if x in prefix_list:
        prefix_list.remove(x)


prefix_list=list(set(prefix_list))
prefix_list.sort()
print(prefix_list)
save_obj(prefix_list,'prefix_list')
# Out:
# ['aao', 'abc', 'abp', 'abs', 'aby', 'adn', 'adz', 'afs', 'aka', 'akph', 'ama', 'ambi', 'annd', 'anx', 'ap', 'apaa', 'apae', 'apak', 'apkh', 'apnh', 'apns', 'aqsh', 'ara', 'arso', 'atfb', 'atid', 'aukg', 'avkh', 'avop', 'bazx', 'bban', 'bcdp', 'bcdv', 'bcv', 'bdsr', 'beb', 'bf', 'bgn', 'blk', 'blor', 'bra', 'bt', 'bur', 'chn', 'cjod', 'club', 'cmi', 'cnd', 'crc', 'crpd', 'cwm', 'dandy', 'dasd', 'davi', 'dbdr', 'dcol', 'ddk', 'dic', 'dism', 'diy', 'djsk', 'dmbl', 'dmdg', 'docp', 'doks', 'dvaj', 'dvdms', 'dwd', 'dxbb', 'ebod', 'edd', 'ekdv', 'emp', 'esk', 'etqr', 
# %% [markdown]
# # 匹配前缀

# %%
prefix_list=load_obj('prefix_list')
 
root=r'g:\1'
folder_one_level(root)
#print(next( os.walk(root) )[1])


for dir_name in next( os.walk(root) )[1]:
    path=os.path.join(root, dir_name)
    
    new_name=dir_name
    prefix=''
    prefix_start=0
    # search prefix
    #print()
    #print('next dir: '+new_name)
    for x in prefix_list:
        prefix_start=new_name.lower().find(x)
        prefix_end=prefix_start+len(x)
        if prefix_end==len(new_name)-1:
            print('strange dir: '+path)
            break
        if prefix_start!=-1:
#                 print(new_name)
#                 print(x)
#                 print(new_name[prefix_end])
            if (new_name[prefix_end]=='-'):
                prefix=x.upper()
                new_name=prefix+new_name[prefix_end:]
                #print(new_name)
                break
            elif new_name[prefix_end].isdigit():
                prefix=x.upper()
                new_name=prefix+'-'+new_name[prefix_end:]
                #print(new_name)
                break
            else:
                print(x+' IN '+path+' BUT NOT COMPLETE')
                print()
    #print('complete')
    if new_name.find('-')==-1:
        print(new_name+'MAY BE WRONG')

    try:
        final_rename(dir_name,new_name,root)
    except Exception as e:
        print(e)
# Out:
# before: g:\1\ABP496C
# after:  g:\1\ABP-496C
#
# before: g:\1\IPX102CMP4
# after:  g:\1\IPX-102CMP4
#
# before: g:\1\MIDE456CMP4
# after:  g:\1\MIDE-456CMP4
#
# before: g:\1\PRTD004C
# after:  g:\1\PRTD-004C
#
# before: g:\1\SDAB045C
# after:  g:\1\SDAB-045C
#
# before: g:\1\SQTE193C
# after:  g:\1\SQTE-193C
#
# before: g:\1\STAR860CMP4
# after:  g:\1\STAR-860CMP4
#
# xv IN g:\1\XVSR-261R BUT NOT COMPLETE
#
# xv IN g:\1\XVSR281CMP4 BUT NOT COMPLETE
#
# before: g:\1\XVSR281CMP4
# after:  g:\1\XVSR-281CMP4
#
# before: g:\1\[789x.me]hnd-564
# after:  g:\1\HND-564
#
# before: g:\1\[789x.me]hnd-575
# after:  g:\1\HND-575

# %% [markdown]
# # 改后缀

# %%
root='g:/1'
for dir_name in next( os.walk(root) )[1]:

    path=os.path.join(root, dir_name)
    if get_size(path)>0:
        new_name=dir_name
        #print()
        #print('next dir: '+new_name)

        #去后缀
        index_dot=new_name.rfind('.')
        if index_dot>0 and index_dot==len(new_name)-4:
            #print('with dot: '+new_name)
            new_name=new_name[:index_dot]
            #print('after: '+new_name)
            
        
            
        index_c=new_name.lower().rfind('c')
        if index_c>0 and index_c==len(new_name)-1:
            if (new_name[len(new_name)-1]=='-') or (new_name[len(new_name)-1]==',') or (new_name[len(new_name)-1]=='_')\
            or (new_name[len(new_name)-1]=='.') or (new_name[len(new_name)-1]==']'):
                new_name=new_name[:len(new_name)-1]
            #print('with dot: '+new_name)
            new_name=new_name[:index_c]+'_CAVI'
            #print('after: '+new_name)
            
        index_c=new_name.rfind('_ch')
        if index_c>0 and index_c==len(new_name)-3:
            new_name=new_name[:index_c]+'_CAVI'
            #print('after: '+new_name)
            
        index_c=new_name.rfind('CMP4')
        if index_c>0 and index_c==len(new_name)-4:
            new_name=new_name[:index_c]+'_CAVI'
            #print('after: '+new_name)
            
        
            
        index_c=new_name.lower().rfind('r')
        if index_c>0 and index_c==len(new_name)-1 and new_name.find('HBR')==-1:
            if (new_name[len(new_name)-1]=='-') or (new_name[len(new_name)-1]==',') or (new_name[len(new_name)-1]=='_')\
            or (new_name[len(new_name)-1]=='.') or (new_name[len(new_name)-1]==']'):
                new_name=new_name[:len(new_name)-1]
            #print('with dot: '+new_name)
            new_name=new_name[:index_c]+'_CAVI'
            #print('after: '+new_name)    
            
        index_c=new_name.rfind('__CAVI')
        if index_c>0:
            new_name=new_name[:index_c]+'_CAVI'
            #print('after: '+new_name)
        
        
        index_c=new_name.rfind('.HD')
        if index_c>0 and index_c==len(new_name)-3:
            #print('with dot: '+new_name)
            new_name=new_name[:index_c]
            #print('after: '+new_name)
        
        index_c=new_name.rfind('CH1080P')
        if index_c>0:
            new_name=new_name[:index_c]+'_CAVI FHD'
            #print('after: '+new_name)

        
        
        #去[thz.la] [.me] [censored]
        is_thz=new_name.lower().find('thz')
        is_me=new_name.lower().find('.me')
        if is_thz!=-1 or is_me!=-1:
            index1=new_name.rfind(']')
            new_name=new_name[index1+1:]

        is_censored=new_name.lower().find('sored]')
        if is_censored!=-1:
            new_name=new_name[is_censored+6:]
            
            
        #HBR
        videopath=largets_file(path)
        indexslash=videopath.rfind('\\')
        firstthree=largets_file(path)[indexslash+1:indexslash+4].lower()
        if firstthree.lower()=='hd-' and new_name.find('HBR')==-1:
            new_name=new_name+' HBR'

            
        
        #最后去垃圾
        if (new_name[len(new_name)-1]=='-') or (new_name[len(new_name)-1]==',') or (new_name[len(new_name)-1]=='_')\
        or (new_name[len(new_name)-1]=='.') or (new_name[len(new_name)-1]==']'):
            new_name=new_name[:len(new_name)-1]
        
        #new_name=new_name.replace('FC2-PPV','FC2PPV')
        final_rename(dir_name,new_name,root)
    
    else:
        print('Empty path:')
        print(path)
        print(' ')
# Out:
# before: g:/1\ABP-496C
# after:  g:/1\ABP-496_CAVI
#
# before: g:/1\ABP-552_48時間耐久連続巨_根アクメ_加藤ほのか.mp4
# after:  g:/1\ABP-552_48時間耐久連続巨_根アクメ_加藤ほのか
#
# before: g:/1\ABP-776.mp4
# after:  g:/1\ABP-776
#
# before: g:/1\GNE-084R
# after:  g:/1\GNE-084_CAVI
#
# Empty path:
# g:/1\HND-548_FHD
#
# before: g:/1\IPX-089R
# after:  g:/1\IPX-089_CAVI
#
# before: g:/1\IPX-102CMP4
# after:  g:/1\IPX-102_CAVI
#
# before: g:/1\JUY-309R
# after:  g:/1\JUY-309_CAVI
#
# before: g:/1\JUY-412R
# after:  g:/1\JUY-412_CAVI
#
# before: g:/1\MIDE-456CMP4
# after:  g:/1\MIDE-456_CAVI
#
# before: g:/1\MIFD-023R
# after:  g:/1\MIFD-023_CAVI
#
# before: g:/1\PIYO-006.mp4
# after:  g:/1\PIYO-006
#
# before: g:/1\PRTD-004C
# after:  g:/1\PRTD-004_CAVI
#
# before: g:/1\SDAB-045C
# after:  g:/1\SDAB-045_CAVI
#
# before: g:/1\SDEN-036.mp4
# after:  g:/1\SDEN-036
#
# before: g:/1\SQTE-193C
# after:  g:/1\SQTE-193_CAVI
#
# before: g:/1\STAR-860CMP4
# after:  g:/1\STAR-860_CAVI
#
# before: g:/1\STAR-976.mp4
# after:  g:/1\STAR-976
#
# before: g:/1\WANZ-681C
# after:  g:/1\WANZ-681_CAVI
#
# before: g:/1\XVSR-261R
# after:  g:/1\XVSR-261_CAVI
#
# before: g:/1\XVSR-281CMP4
# after:  g:/1\XVSR-281_CAVI

# %% [markdown]
# # 收集垃圾

# %%
trash('g:/1')
# Out:
# -----------------------------------------------------------
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# NOW COLLECT TRASH UNDER g:/1
# - - - - - - - - - - - - - - - - - - - - - - - - - - - - - -
# trash collected in g:/1/ABP-496_CAVI:
#
# trash collected in g:/1/GNE-084_CAVI:
#
# trash collected in g:/1/HND-564:
#
# trash collected in g:/1/HND-575:
#
# trash collected in g:/1/IPX-089_CAVI:
#
# trash collected in g:/1/IPX-102_CAVI:
#
# trash collected in g:/1/JUY-309_CAVI:
#
# trash collected in g:/1/JUY-412_CAVI:
#
# trash collected in g:/1/MIDE-456_CAVI:
#
# trash collected in g:/1/MIFD-023_CAVI:
#
# trash collected in g:/1/PRTD-004_CAVI:
#
# trash collected in g:/1/SDAB-045_CAVI:
#
# trash collected in g:/1/SQTE-193_CAVI:
#
# trash collected in g:/1/STAR-860_CAVI:
#
# trash collected in g:/1/WANZ-681_CAVI:
#
# trash collected in g:/1/XVSR-261_CAVI:
#
# trash collected in g:/1/XVSR-281_CAVI:
#
# -----------------------------------------------------------
# -----------------------------------------------------------

# %% [markdown]
# # G2

# %%
root_path=r'g:\2'
for dir_name in next( os.walk(root_path) )[1]:
    path=os.path.join(root_path, dir_name)
    print(path)
    folder_one_level(path,0)
# Out:
# g:\2\pics
# g:\2\pics/adn176.jpg
# g:\2\pics/adn176/adn176.jpg
# g:\2\pics/cmi-141.jpg
# g:\2\pics/cmi-141/cmi-141.jpg
# g:\2\pics/desktop.ini
# g:\2\pics/desktop/desktop.ini
# g:\2\pics/fone005.jpg
# g:\2\pics/fone005/fone005.jpg
# g:\2\pics/ipx196.jpg
# g:\2\pics/ipx196/ipx196.jpg
# g:\2\pics/meyd410.jpg
# g:\2\pics/meyd410/meyd410.jpg
# g:\2\pics/miae294.jpg
# g:\2\pics/miae294/miae294.jpg
# g:\2\pics/sdmu869.jpg
# g:\2\pics/sdmu869/sdmu869.jpg
# g:\2\pics/ssni235.jpg
# g:\2\pics/ssni235/ssni235.jpg
# g:\2\pics/star953.jpg
# g:\2\pics/star953/star953.jpg
# g:\2\pics/t28534.jpg
# g:\2\pics/t28534/t28534.jpg
# g:\2\vids

# %%
root=r'g:\2\pics'
for dir_name in next( os.walk(root) )[1]:
    path=os.path.join(root, dir_name)
    new_name=dir_name
    indexh=new_name.find('-')
    if indexh!=-1:
        new_name=new_name[:indexh]+new_name[indexh+1:]
        print(new_name[:indexh])
        print(new_name[indexh:])
    new_name=new_name.upper()
    new_name=new_name+'_ch'

    final_rename(dir_name,new_name,root)
# Out:
# before: g:\2\pics\adn176
# after:  g:\2\pics\ADN176_ch
#
# cmi
# 141
# before: g:\2\pics\cmi-141
# after:  g:\2\pics\CMI141_ch
#
# before: g:\2\pics\desktop
# after:  g:\2\pics\DESKTOP_ch
#
# before: g:\2\pics\fone005
# after:  g:\2\pics\FONE005_ch
#
# before: g:\2\pics\ipx196
# after:  g:\2\pics\IPX196_ch
#
# before: g:\2\pics\meyd410
# after:  g:\2\pics\MEYD410_ch
#
# before: g:\2\pics\miae294
# after:  g:\2\pics\MIAE294_ch
#
# before: g:\2\pics\sdmu869
# after:  g:\2\pics\SDMU869_ch
#
# before: g:\2\pics\ssni235
# after:  g:\2\pics\SSNI235_ch
#
# before: g:\2\pics\star953
# after:  g:\2\pics\STAR953_ch
#
# before: g:\2\pics\t28534
# after:  g:\2\pics\T28534_ch

# %% [markdown]
# # 新项目

# %%
for filename in next(os.walk('g:/2/pics'))[2]:
    indexspace=filename.find(' ')
    if indexspace!=-1:
        new_name=filename[indexspace+1:]
        path='g:/2/pics/'+filename
        dst='g:/2/pics/'+new_name
        os.rename(path,dst)

# %%
folder_one_level('f:/1/vids')
# Out:
# f:/1/vids/259LUXU-975.FHD@b1b1s9.com.mkv
# f:/1/vids/259LUXU-975.FHD@b1b1s9.com/259LUXU-975.FHD@b1b1s9.com.mkv
# f:/1/vids/259LUXU-978.FHD.mkv
# f:/1/vids/259LUXU-978.FHD/259LUXU-978.FHD.mkv
# f:/1/vids/259LUXU-979.FHD.mkv
# f:/1/vids/259LUXU-979.FHD/259LUXU-979.FHD.mkv
# f:/1/vids/259LUXU-980.FHD.mkv
# f:/1/vids/259LUXU-980.FHD/259LUXU-980.FHD.mkv
# f:/1/vids/259LUXU-981.FHD.mkv
# f:/1/vids/259LUXU-981.FHD/259LUXU-981.FHD.mkv
# f:/1/vids/259LUXU-982.FHD@RUNBKK.mkv
# f:/1/vids/259LUXU-982.FHD@RUNBKK/259LUXU-982.FHD@RUNBKK.mkv
# f:/1/vids/259LUXU-983.FHD.mkv
# f:/1/vids/259LUXU-983.FHD/259LUXU-983.FHD.mkv
# f:/1/vids/259LUXU-984.FHD.mkv
# f:/1/vids/259LUXU-984.FHD/259LUXU-984.FHD.mkv
# f:/1/vids/259LUXU-985.FHD.mkv
# f:/1/vids/259LUXU-985.FHD/259LUXU-985.FHD.mkv
# f:/1/vids/259LUXU-986.FHD.mkv
# f:/1/vids/259LUXU-986.FHD/259LUXU-986.FHD.mkv
# f:/1/vids/259LUXU-987.FHD.mkv
# f:/1/vids/259LUXU-987.FHD/259LUXU-987.FHD.mkv
# f:/1/vids/259LUXU-988.FHD@RUNBKK.mkv
# f:/1/vids/259LUXU-988.FHD@RUNBKK/259LUXU-988.FHD@RUNBKK.mkv
# f:/1/vids/259LUXU-989.FHD.mkv
