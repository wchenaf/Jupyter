# %%
import import_ipynb
import searchsub
import findrep
from searchsub import findmag

# %%
for i in range(720,730):
    num= '%03d' % i
    findmag('abp',num)
# Out:
# ABP-720开始搜索:
#
# abp-720r有带字幕链接
# 网址：
# https://m.zhongziso.com/list/abp-720r/1
# 磁力链接：
# magnet:?xt=urn:btih:bd5da9b49043a4d20a1cb70ef9b9c9f54ad37ddb
# magnet:?xt=urn:btih:a9441d069e19c15ac4302ded6b3930c8199ae40f
#
# abp720c有带字幕链接
# 网址：
# https://m.zhongziso.com/list/abp720c/1
# 磁力链接：
# magnet:?xt=urn:btih:d5a19b6fc1f29229f79b04b62ddc92891d0b1a64
# magnet:?xt=urn:btih:c3656d368205c466b3a608032ccc25db5aa25b91
#
# -------------------------------------------------------------------------
#
# ABP-721开始搜索:
#
# abp-721r有带字幕链接
# 网址：
# https://m.zhongziso.com/list/abp-721r/1
# 磁力链接：
# magnet:?xt=urn:btih:3648f0a994f388ae2409468407da9814965aabc5
#
# abp721c有带字幕链接
# 网址：
# https://m.zhongziso.com/list/abp721c/1
# 磁力链接：
# magnet:?xt=urn:btih:e9e4768bcf6766a20c88c60e33f3d781dd287231
#
# abp721cmp4有带字幕链接
# 网址：
# https://m.zhongziso.com/list/abp721cmp4/1
# 磁力链接：
# magnet:?xt=urn:btih:2c230d72514ad727dd91c4e2248a25da43776573
#
# ...

# %%
findrep.nonsublist
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-21-cb4d5afb7e5e> in <module>()
# ----> 1 findrep.nonsublist
#
# AttributeError: module 'findrep' has no attribute 'nonsublist'
